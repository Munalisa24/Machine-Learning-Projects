# %% [markdown]
# ## BUSINESS CASE:
#
# ### Based on the given features predict the various  customer interactions or transactions, likely in a sales or service context..

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('C:\\Users\\munal\\Desktop\\data.csv')
data
# Out:
#                Created  Product_ID            Source      Mobile  \
# 0     14-11-2018 10:05         NaN           Website  984XXXXXXX
# 1     14-11-2018 09:22         NaN           Website     XXXXXXX
# 2     14-11-2018 09:21         NaN           Website     XXXXXXX
# 3     14-11-2018 08:46         NaN           Website     XXXXXXX
# 4     14-11-2018 07:34         NaN           Website     XXXXXXX
# ...                ...         ...               ...         ...
# 7417  28-04-2018 09:45         9.0              Call         NaN
# 7418  28-04-2018 09:43        15.0              Call         NaN
# 7419  28-04-2018 09:20         5.0  Live Chat-Direct         NaN
# 7420  28-04-2018 08:04        21.0          CRM form         NaN
# 7421  28-04-2018 07:54        25.0           Website         NaN
#
#                    EMAIL     Sales_Agent         Location Delivery_Mode  \
# 0     aXXXXXXX@gmail.com  Sales-Agent-11              NaN        Mode-5
# ...

# %% [markdown]
# ## BASIC CHECKS:

# %%
data.shape
# Out:
# (7422, 9)

# %%
data.head()
# Out:
#             Created  Product_ID   Source      Mobile               EMAIL  \
# 0  14-11-2018 10:05         NaN  Website  984XXXXXXX  aXXXXXXX@gmail.com
# 1  14-11-2018 09:22         NaN  Website     XXXXXXX             #VALUE!
# 2  14-11-2018 09:21         NaN  Website     XXXXXXX  dXXXXXXX@yahoo.com
# 3  14-11-2018 08:46         NaN  Website     XXXXXXX  wXXXXXXX@gmail.com
# 4  14-11-2018 07:34         NaN  Website     XXXXXXX  cXXXXXXX@gmail.com
#
#       Sales_Agent Location Delivery_Mode Status
# 0  Sales-Agent-11      NaN        Mode-5   Open
# 1  Sales-Agent-10      NaN        Mode-5   Open
# 2  Sales-Agent-10      NaN        Mode-5   Open
# 3  Sales-Agent-10      NaN        Mode-5   Open
# 4  Sales-Agent-10      NaN        Mode-5   Open

# %%
data.tail()
# Out:
#                Created  Product_ID            Source Mobile  \
# 7417  28-04-2018 09:45         9.0              Call    NaN
# 7418  28-04-2018 09:43        15.0              Call    NaN
# 7419  28-04-2018 09:20         5.0  Live Chat-Direct    NaN
# 7420  28-04-2018 08:04        21.0          CRM form    NaN
# 7421  28-04-2018 07:54        25.0           Website    NaN
#
#                    EMAIL     Sales_Agent         Location Delivery_Mode  \
# 7417  aXXXXXXX@gmail.com   Sales-Agent-6           Mumbai        Mode-4
# 7418             #VALUE!  Sales-Agent-12  Other Locations        Mode-5
# 7419  sXXXXXXX@gmail.com  Sales-Agent-11        Bangalore        Mode-1
# 7420  YXXXXXXX@gmail.com   Sales-Agent-4  Other Locations        Mode-1
# 7421  cXXXXXXX@gmail.com   Sales-Agent-3          Chennai        Mode-1
#
#               Status
# 7417            LOST
# 7418            LOST
# 7419  Not Responding
# 7420    Just Enquiry
# 7421       CONVERTED

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7422 entries, 0 to 7421
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Created        7422 non-null   object
#  1   Product_ID     7364 non-null   float64
#  2   Source         7405 non-null   object
#  3   Mobile         5612 non-null   object
#  4   EMAIL          7422 non-null   object
#  5   Sales_Agent    7399 non-null   object
#  6   Location       7364 non-null   object
#  7   Delivery_Mode  7422 non-null   object
#  8   Status         7422 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 522.0+ KB

# %%
data.describe()
# Out:
#         Product_ID
# count  7364.000000
# mean     15.947311
# std       6.072937
# min       0.000000
# 25%      12.000000
# 50%      18.000000
# 75%      19.000000
# max      28.000000

# %%
data.describe(include='O')
# Out:
#                  Created Source   Mobile    EMAIL    Sales_Agent  \
# count               7422   7405     5612     7422           7399
# unique              6752     25      486      883             12
# top     26-09-2018 11:30   Call  XXXXXXX  #VALUE!  Sales-Agent-4
# freq                   4   2547      222     1701           1500
#
#                Location Delivery_Mode     Status
# count              7364          7422       7422
# unique               17             5         11
# top     Other Locations        Mode-5  Junk Lead
# freq               2500          2975       1536

# %%
data.isnull().sum()
# Out:
# Created             0
# Product_ID         58
# Source             17
# Mobile           1810
# EMAIL               0
# Sales_Agent        23
# Location           58
# Delivery_Mode       0
# Status              0
# dtype: int64

# %%
#we have null values in our data.

# %% [markdown]
# ## DOMAIN ANALYSIS

# %% [markdown]
# ### Domain Analysis: Data-Driven Insights for Business Efficiency
#
# #### Industry Overview
# - **Sector Description**: This project is situated in the domain of data-driven business analysis, likely targeting sectors such as retail, e-commerce, or customer service where data analytics plays a crucial role in decision-making.
# - **Market Size and Growth**: The market for data analytics in business is substantial and growing, driven by the increasing availability of data and the need for informed decision-making.
# - **Trends and Drivers**: The key trend is the growing reliance on data for strategic decisions, including customer behavior analysis, inventory management, and sales forecasting.
#
# #### Data Utilization Landscape
# - **Nature of Data**: The notebook indicates the use of a dataset involving dimensions like sales, customer demographics, or inventory (as inferred from the initial checks like `data.shape`).
# - **Data Analysis Techniques**: The methods used in the notebook (such as statistical analysis, data visualization) reflect an emphasis on extracting actionable insights from complex datasets.
# - **Competitive Advantage**: The ability to efficiently analyze and interpret data can provide a competitive edge in formulating business strategies and operational efficiencies.
#
# #### Customer and Market Analysis
# - **Target Audience for Analysis**: The primary users of these insights would be business managers, marketers, and strategists looking for data-driven ways to improve performance.
# - **Market Demand**: There's a high demand in various sectors for robust data analysis to guide business decisions and to identify market opportunities and customer preferences.
#
# #### Technological Context
# - **Tools and Technologies**: The use of Python libraries like Pandas, NumPy, and visualization tools like Seaborn and Matplotlib, places this project in the realm of advanced data analytics.
# - **Innovation and Trends**: Trends in this domain include the integration of machine learning for predictive analysis and the use of big data technologies.
#
# #### Regulatory and Ethical Considerations
# - **Data Privacy and Ethics**: Any data analysis should comply with data protection regulations (like GDPR) and ethical guidelines, especially when dealing with customer data.
# - **Data Handling and Security**: The notebook's approach must ensure secure and compliant handling of data throughout the analysis process.
#
# #### Challenges and Opportunities
# - **Challenges**: Include ensuring data quality, managing large volumes of data, and translating data insights into actionable business strategies.
# - **Opportunities**: Using data-driven insights for market segmentation, personalized marketing strategies, and optimizing operational processes.
#
# #### Future Outlook
# - **Short-term Outlook**: Enhancing current business strategies with more data-driven decisions.
# - **Long-term Outlook**: Potentially evolving the analysis to include predictive modeling and AI-driven insights for strategic planning.
#
# This domain analysis is specific to the data analysis and business intelligence context as indicated in your Jupyter notebook. It focuses on leveraging data analytics for improved business decision-making, aligning with the tools and preliminary analysis demonstrated in the notebook.

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
# univariate analysis
# !pip install sweetviz

# %%
import sweetviz as sv #importing sweetviz library 
report = sv.analyze(data)
report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
##bivariate:


# Dataset dimensions - rows and columns
print("Dataset dimensions:", data.shape)

# Columns in the dataset
print("Dataset columns:", data.columns)

# Data types of the columns
print("Data types:", data.dtypes)

# Checking for missing values
print("Missing values:", data.isnull().sum())

# Basic descriptive statistics
print("Descriptive Statistics:\n", data.describe())

# For categorical data
print("Description of categorical data:\n", data.describe(include='object'))

# Pairplot to visualize relationships between numerical variables
sns.pairplot(data)
plt.show()

# Correlation matrix heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# Histograms for all numerical variables
data.hist(bins=15, figsize=(15, 10))
plt.show()

# Box plots for numerical variables to check for outliers
for column in data.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(7, 4))
    sns.boxplot(data=data, x=column)
    plt.title(f'Boxplot of {column}')
    plt.show()

# Count plots for categorical variables
for column in data.select_dtypes(include='object').columns:
    plt.figure(figsize=(7, 4))
    sns.countplot(data=data, x=column)
    plt.title(f'Countplot of {column}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## DATA PREPROCESSING:

# %%
## Getting the rows where values are missed in total_stops feature:
data.loc[data['Product_ID'].isnull()==True]
# Out:
#                Created  Product_ID            Source      Mobile  \
# 0     14-11-2018 10:05         NaN           Website  984XXXXXXX
# 1     14-11-2018 09:22         NaN           Website     XXXXXXX
# 2     14-11-2018 09:21         NaN           Website     XXXXXXX
# 3     14-11-2018 08:46         NaN           Website     XXXXXXX
# 4     14-11-2018 07:34         NaN           Website     XXXXXXX
# 5     14-11-2018 07:33         NaN           Website     XXXXXXX
# 6     14-11-2018 05:58         NaN           Website     XXXXXXX
# 7     14-11-2018 05:49         NaN           Website     XXXXXXX
# 8     14-11-2018 05:40         NaN           Website  078XXXXXXX
# 9     14-11-2018 05:06         NaN           Website     XXXXXXX
# 10    14-11-2018 05:03         NaN           Website     XXXXXXX
# 11    14-11-2018 04:52         NaN           Website     XXXXXXX
# 12    14-11-2018 02:37         NaN           Website  467XXXXXXX
# ...

# %%
## Checking the distribution along the labels
data.Product_ID.value_counts()
# Out:
# 18.0    1711
# 15.0    1518
# 19.0    1189
# 9.0      992
# 27.0     739
# 5.0      487
# 10.0     168
# 1.0      105
# 20.0     102
# 25.0      90
# 21.0      66
# 2.0       38
# 12.0      36
# 26.0      31
# 14.0      27
# 11.0      12
# 22.0       8
# 3.0        7
# 17.0       7
# 6.0        7
# 8.0        6
# 13.0       5
# 24.0       3
# 16.0       3
# 23.0       2
# 0.0        2
# 28.0       1
# 7.0        1
# 4.0        1
# Name: Product_ID, dtype: int64

# %%
data.loc[data['Source'].isnull()==True]
# Out:
#                Created  Product_ID Source      Mobile               EMAIL  \
# 13    13-11-2018 23:40         NaN    NaN     XXXXXXX             #VALUE!
# 15    13-11-2018 20:45         NaN    NaN     XXXXXXX             #VALUE!
# 21    13-11-2018 18:25         NaN    NaN     XXXXXXX             #VALUE!
# 128   10-11-2018 20:40         NaN    NaN     XXXXXXX             #VALUE!
# 138   10-11-2018 18:00         NaN    NaN     XXXXXXX             #VALUE!
# 2518  30-08-2018 20:40        18.0    NaN  961XXXXXXX  kXXXXXXXahoo.co.in
# 2556  29-08-2018 19:41         NaN    NaN     XXXXXXX             #VALUE!
# 2686  26-08-2018 11:10         9.0    NaN  916XXXXXXX  dXXXXXXX@gmail.com
# 2712  25-08-2018 10:00        15.0    NaN  998XXXXXXX  sXXXXXXX@gmail.com
# 2767  23-08-2018 14:40        15.0    NaN  995XXXXXXX             #VALUE!
# 3051  15-08-2018 21:44         NaN    NaN     XXXXXXX             #VALUE!
# 4979  25-06-2018 16:31         NaN    NaN     XXXXXXX             #VALUE!
# ...

# %%
data.Source.value_counts()
# Out:
# Call                             2547
# Live Chat-Direct                 1834
# Website                          1594
# Live Chat-Google Organic          274
# Live Chat -PPC                    249
# Live Chat-Blog                    237
# Customer Referral                 180
# US Website                        137
# Just Dial                          56
# Existing Client                    51
# Personal Contact                   50
# Live Chat-CPC                      50
# By Recommendation                  32
# CRM form                           23
# Existing Customer                  22
# Live Chat-Google Ads               21
# Campaign                           19
# E-mail Campaign                    12
# Live Chat-Adwords Remarketing       7
# Live Chat-Quora                     2
# Other                               2
# SMS Campaign                        2
# Live Chat-Youtube                   2
# E-Mail Message                      1
# Live Chat-Justdial                  1
# ...

# %%
data.loc[data['Sales_Agent'].isnull()==True]
# Out:
#                Created  Product_ID                    Source      Mobile  \
# 118   11-11-2018 12:35         5.0      Live Chat-Google Ads  986XXXXXXX
# 593   25-10-2018 18:02        15.0          Live Chat-Direct  854XXXXXXX
# 651   24-10-2018 11:01        18.0                   Website  987XXXXXXX
# 658   24-10-2018 10:18        17.0  Live Chat-Google Organic     XXXXXXX
# 681   23-10-2018 12:09        15.0  Live Chat-Google Organic     XXXXXXX
# 690   23-10-2018 11:33        15.0                      Call  904XXXXXXX
# 691   23-10-2018 11:31        15.0                      Call  903XXXXXXX
# 884   16-10-2018 10:06        24.0                      Call  952XXXXXXX
# 1109  09-10-2018 12:55        18.0          Live Chat-Direct  988XXXXXXX
# 1490  27-09-2018 11:00        15.0                      Call  776XXXXXXX
# 1734  21-09-2018 10:42        15.0                      Call  831XXXXXXX
# 2946  19-08-2018 14:00        19.0  Live Chat-Google Organic  803XXXXXXX
# ...

# %%
data.Sales_Agent.value_counts()
# Out:
# Sales-Agent-4     1500
# Sales-Agent-11    1420
# Sales-Agent-5     1190
# Sales-Agent-9      879
# Sales-Agent-3      781
# Sales-Agent-7      736
# Sales-Agent-2      389
# Sales-Agent-12     269
# Sales-Agent-6      114
# Sales-Agent-8       68
# Sales-Agent-10      49
# Sales-Agent-1        4
# Name: Sales_Agent, dtype: int64

# %%
data.loc[data['Location'].isnull()==True]
# Out:
#                Created  Product_ID            Source      Mobile  \
# 0     14-11-2018 10:05         NaN           Website  984XXXXXXX
# 1     14-11-2018 09:22         NaN           Website     XXXXXXX
# 2     14-11-2018 09:21         NaN           Website     XXXXXXX
# 3     14-11-2018 08:46         NaN           Website     XXXXXXX
# 4     14-11-2018 07:34         NaN           Website     XXXXXXX
# 5     14-11-2018 07:33         NaN           Website     XXXXXXX
# 6     14-11-2018 05:58         NaN           Website     XXXXXXX
# 7     14-11-2018 05:49         NaN           Website     XXXXXXX
# 8     14-11-2018 05:40         NaN           Website  078XXXXXXX
# 9     14-11-2018 05:06         NaN           Website     XXXXXXX
# 10    14-11-2018 05:03         NaN           Website     XXXXXXX
# 11    14-11-2018 04:52         NaN           Website     XXXXXXX
# 12    14-11-2018 02:37         NaN           Website  467XXXXXXX
# ...

# %%
data.Location.value_counts()
# Out:
# Other Locations    2500
# Bangalore          2084
# Chennai             909
# Hyderabad           528
# Delhi               471
# Mumbai              402
# Pune                142
# UAE                  79
# Trivandrum           58
# Kolkata              55
# USA                  45
# UK                   41
# AUSTRALIA            25
# Singapore            17
# Malaysia              4
# EUROPE                3
# Howrah                1
# Name: Location, dtype: int64

# %%
data.loc[data['Status'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Created, Product_ID, Source, Mobile, EMAIL, Sales_Agent, Location, Delivery_Mode, Status]
# Index: []

# %%
data.Status.value_counts()
# Out:
# Junk Lead               1536
# Not Responding          1129
# CONVERTED                834
# Just Enquiry             760
# Potential                708
# Long Term                646
# In Progress Positive     643
# In Progress Negative     626
# LOST                     440
# Open                      82
# converted                 18
# Name: Status, dtype: int64

# %%
#dropping the unwanted columns:
data.drop(columns=['Mobile','Created','EMAIL'],inplace=True)

# %%
data.head()
# Out:
#    Product_ID   Source     Sales_Agent Location Delivery_Mode Status
# 0         NaN  Website  Sales-Agent-11      NaN        Mode-5   Open
# 1         NaN  Website  Sales-Agent-10      NaN        Mode-5   Open
# 2         NaN  Website  Sales-Agent-10      NaN        Mode-5   Open
# 3         NaN  Website  Sales-Agent-10      NaN        Mode-5   Open
# 4         NaN  Website  Sales-Agent-10      NaN        Mode-5   Open

# %%
data.isnull().sum()
# Out:
# Product_ID       58
# Source           17
# Sales_Agent      23
# Location         58
# Delivery_Mode     0
# Status            0
# dtype: int64

# %%
data.shape
# Out:
# (7422, 6)

# %%
#dropping those missing values:
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Product_ID       0
# Source           0
# Sales_Agent      0
# Location         0
# Delivery_Mode    0
# Status           0
# dtype: int64

# %%
data.shape
# Out:
# (7328, 6)

# %%
# NO NULL VALUES

# %% [markdown]
# ## FEATURE ENCODING:

# %%
# Defining 'Status' as 'Good' or 'Bad'
data.Status.replace(['CONVERTED','converted','In Progress Positive','Potential','Long Term','Open'],'1',inplace=True)
data.Status.replace(['LOST','In Progress Negative','Not Responding','Junk Lead','Just Enquiry'],'0',inplace=True)

# %%
data.head()
# Out:
#     Product_ID                    Source     Sales_Agent         Location  \
# 18         9.0  Live Chat-Google Organic   Sales-Agent-3        Bangalore
# 19        19.0                      Call   Sales-Agent-4  Other Locations
# 24        18.0                   Website  Sales-Agent-11       Trivandrum
# 25        15.0                   Website   Sales-Agent-7        Hyderabad
# 26        18.0                      Call   Sales-Agent-7        Bangalore
#
#    Delivery_Mode Status
# 18        Mode-1      1
# 19        Mode-5      1
# 24        Mode-1      1
# 25        Mode-1      0
# 26        Mode-1      1

# %%
data['Product_ID'].replace(
    [8.0, 6.0, 3.0, 17.0, 22.0, 11.0, 7.0, 28.0, 0.0, 23.0, 24.0, 16.0, 13.0, 4.0, 14.0, 26.0, 12.0, 2.0, 21.0, 25.0],
    'lesssold',
    inplace=True
)

data['Product_ID'].replace(
    [18.0, 15.0, 19.0, 9.0, 27.0, 5.0, 10.0, 1.0, 20.0],
    'highsold',
    inplace=True
)

# %%
data.head(5)
# Out:
#    Product_ID                    Source     Sales_Agent         Location  \
# 18   highsold  Live Chat-Google Organic   Sales-Agent-3        Bangalore
# 19   highsold                      Call   Sales-Agent-4  Other Locations
# 24   highsold                   Website  Sales-Agent-11       Trivandrum
# 25   highsold                   Website   Sales-Agent-7        Hyderabad
# 26   highsold                      Call   Sales-Agent-7        Bangalore
#
#    Delivery_Mode Status
# 18        Mode-1      1
# 19        Mode-5      1
# 24        Mode-1      1
# 25        Mode-1      0
# 26        Mode-1      1

# %%
data.Location.replace(['UAE','USA','UK','AUSTRALIA','Singapore','Malaysia','EUROPE'],'Foreign',inplace=True)
data.Location.replace(['Howrah','Kolkata','Trivandrum'],'Other Locations',inplace=True)

# %%
data.Source.replace(['Live Chat-Direct','Live Chat-Google Organic','Live Chat -PPC','Live Chat-Blog','Live Chat-Quora',
                    'Live Chat-CPC','Live Chat-Google Ads','Live Chat-Adwords Remarketing','Live Chat-Youtube',
                    'Live Chat-Justdial'],'Live Chat',inplace=True)
data.Source.replace(['Existing Client','CRM form','Personal Contact'],'Existing Customer',inplace=True)
data.Source.replace('By Recommendation','Customer Referral',inplace=True)
data.Source.replace(['US Website','Just Dial'],'Website',inplace=True)
data.Source.replace(['E-mail Campaign','SMS Campaign','E-Mail Message','Other'],'Campaign',inplace=True)

# %%
data['Source'].replace(
    ['Live Chat-Direct', 'Live Chat-Google Organic', 'Live Chat -PPC', 'Live Chat-Blog', 'Live Chat-Quora',
     'Live Chat-CPC', 'Live Chat-Google Ads', 'Live Chat-Adwords Remarketing', 'Live Chat-Youtube', 'Live Chat-Justdial'],
    'Live Chat',
    inplace=True
)

data['Source'].replace(
    ['Existing Client', 'CRM form', 'Personal Contact'],
    'Existing Customer',
    inplace=True
)

data['Source'].replace('By Recommendation', 'Customer Referral', inplace=True)

data['Source'].replace(['US Website', 'Just Dial'], 'Website', inplace=True)

data['Source'].replace(['E-mail Campaign', 'SMS Campaign', 'E-Mail Message', 'Other'], 'Campaign', inplace=True)

# %%
data.head()
# Out:
#    Product_ID     Source     Sales_Agent         Location Delivery_Mode Status
# 18   highsold  Live Chat   Sales-Agent-3        Bangalore        Mode-1      1
# 19   highsold       Call   Sales-Agent-4  Other Locations        Mode-5      1
# 24   highsold    Website  Sales-Agent-11  Other Locations        Mode-1      1
# 25   highsold    Website   Sales-Agent-7        Hyderabad        Mode-1      0
# 26   highsold       Call   Sales-Agent-7        Bangalore        Mode-1      1

# %%
data.Location.replace(['UAE','USA','UK','AUSTRALIA','Singapore','Malaysia','EUROPE'],'Foreign',inplace=True)

# %%
data.head()
# Out:
#    Product_ID     Source     Sales_Agent         Location Delivery_Mode Status
# 18   highsold  Live Chat   Sales-Agent-3        Bangalore        Mode-1      1
# 19   highsold       Call   Sales-Agent-4  Other Locations        Mode-5      1
# 24   highsold    Website  Sales-Agent-11  Other Locations        Mode-1      1
# 25   highsold    Website   Sales-Agent-7        Hyderabad        Mode-1      0
# 26   highsold       Call   Sales-Agent-7        Bangalore        Mode-1      1

# %%
## Using label encoder to convert the categorical data to numerical data

# Ordinal data features

from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()

data.Product_ID=lc.fit_transform(data.Product_ID)
data.Source=lc.fit_transform(data.Source)
data.Sales_Agent=lc.fit_transform(data.Sales_Agent)
data.Location=lc.fit_transform(data.Location)
data.Delivery_Mode=lc.fit_transform(data.Delivery_Mode)

# %%
data.head()
# Out:
#     Product_ID  Source  Sales_Agent  Location  Delivery_Mode Status
# 18           0       4            4         0              0      1
# 19           0       0            5         6              4      1
# 24           0       5            1         6              0      1
# 25           0       5            8         4              0      0
# 26           0       0            8         0              0      1

# %%
data.Status.value_counts()
# Out:
# 0    4466
# 1    2862
# Name: Status, dtype: int64

# %% [markdown]
# ## FEATURE SELECTION:

# %%
## Checking correlation

plt.figure(figsize=(40, 40))#canvas size
sns.heatmap(data.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":20})#plotting heat map to check correlation
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## MODEL CREATION:

# %%
## Creating independent and dependent variable
X = data.drop('Status', axis=1) #independent variable 
Y = data.Status #dependent variable

# %%
X.head()
# Out:
#     Product_ID  Source  Sales_Agent  Location  Delivery_Mode
# 18           0       4            4         0              0
# 19           0       0            5         6              4
# 24           0       5            1         6              0
# 25           0       5            8         4              0
# 26           0       0            8         0              0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (5862, 5)

# %% [markdown]
# ## LOGISTIC REGRESSION:

# %%
## Step 3 Model creation
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

clf.fit(X_train,y_train)  ## training
# Out:
# LogisticRegression()

# %%
## Step 4 Prediction
y_pred=clf.predict(X_test)

# %%
y_pred
# Out:
# array(['0', '0', '0', ..., '0', '1', '0'], dtype=object)

# %%
y_test
# Out:
# 2628    0
# 1610    0
# 908     0
# 5853    0
# 3798    0
#        ..
# 79      1
# 4066    1
# 4495    0
# 563     1
# 1836    1
# Name: Status, Length: 1466, dtype: object

# %%
y_pred_prob=clf.predict_proba(X_test)   #probability function=predict_proba

# %%
y_pred_prob   #probability of 0 , 1
# Out:
# array([[0.85455646, 0.14544354],
#        [0.74654007, 0.25345993],
#        [0.75777624, 0.24222376],
#        ...,
#        [0.85455646, 0.14544354],
#        [0.31393377, 0.68606623],
#        [0.50180596, 0.49819404]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score, precision_score,classification_report,f1_score

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[680 190]
#  [282 314]]

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0     0    1
# Status
# 0       680  190
# 1       282  314

# %%
Acc = accuracy_score(y_test,y_pred)
Acc
# Out:
# 0.6780354706684857

# %% [markdown]
# ## K-NEIGHBORS CLASSIFIER:

# %%
from sklearn.neighbors import KNeighborsClassifier  #it is classification task

# %%
## taking optimal k to determine how many nearest neighbors  to create

# create a list to store the error values for each k
error_rate = []

# Will take some time  finding the k value
for i in range(1,11):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)   #pred_i=predicted o/p
    error_rate.append(np.mean(pred_i != y_test)) #ytest---actual o/p
    # if predicted value is not equal to actual value, returns true (which is taken as 1) else false(0). 
    # Adds all the value and takes mean of it. So for each k-value, gets the mean of error.
    #print(np.mean(pred_i != y_test))

# %%
# Lets plot the finded k-value and error rate

plt.figure(figsize=(10,6))
plt.plot(range(1,11),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
# let's fit the data into KNN model and see how well it performs:
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train,y_train)# Predict 
y_pred = knn.predict(X_test)

# %%
# Checking Accuracy score
print("The accuracy score is : ", accuracy_score(y_test,y_pred))
# Out:
# The accuracy score is :  0.6862210095497954

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75       870
#            1       0.63      0.54      0.58       596
#
#     accuracy                           0.69      1466
#    macro avg       0.67      0.66      0.67      1466
# weighted avg       0.68      0.69      0.68      1466

# %%
from sklearn.ensemble import BaggingClassifier #import bagging 

## model object creation
model_bagg1=BaggingClassifier(base_estimator=knn,n_estimators=300) 

# base_estimator---> algorithm which you want to pass
# n_estimators-----> number of base learners


## fitting the model
model_bagg1.fit(X_train,y_train) 


## getting the prediction
y_hat_bagg=model_bagg1.predict(X_test)

# %%
f1_bagg=f1_score(y_test,y_hat_bagg,average='weighted') ## The weighted-averaged F1 score is calculated by taking 
                                             ## the mean of all per-class F1 scores while considering each class’s support.

# %%
f1_bagg #score after bagging
# Out:
# 0.6914516132524007

# %%
# Checking Accuracy score
print("The accuracy score is : ", accuracy_score(y_test,y_hat_bagg))
# Out:
# The accuracy score is :  0.6964529331514324

# %% [markdown]
# ## SMOTING TECHNIQUE- to balance the data

# %%
# !pip install imblearn

# %%
# Apply SMOTE to balance the data
from imblearn.over_sampling import SMOTE
smote = SMOTE() ## object creation

# %%
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
from collections import Counter #USING COUNTER U CAN RECHECK
print("Actual Classes",Counter(y_train))
print("SMOTE Classes",Counter(y_train_smote))
# Out:
# Actual Classes Counter({'0': 3596, '1': 2266})
# SMOTE Classes Counter({'0': 3596, '1': 3596})

# %% [markdown]
# ## SUPPORT VECTOR MACHINE:

# %%
# Support Vector Classifier Model

from sklearn.svm import SVC
svclassifier = SVC() ## base model with default parameters
svclassifier.fit(X_train_smote, y_train_smote)
# Out:
# SVC()

# %%
# Predict output for X_test

y_hat=svclassifier.predict(X_test)

# %%
## evaluating the model created
from sklearn.metrics import accuracy_score,classification_report,f1_score
acc=accuracy_score(y_test,y_hat)
acc
# Out:
# 0.6609822646657572

# %%
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.62      0.69       870
#            1       0.57      0.72      0.63       596
#
#     accuracy                           0.66      1466
#    macro avg       0.66      0.67      0.66      1466
# weighted avg       0.68      0.66      0.66      1466

# %%
cm1=pd.crosstab(y_test,y_hat)
cm1
# Out:
# col_0     0    1
# Status
# 0       542  328
# 1       169  427

# %% [markdown]
# ### HYPERPARAMETER TUNNING:

# %%
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]} 

grid = GridSearchCV(SVC(random_state=42), param_grid, verbose =1,scoring='f1',cv=3)
  
# fitting the model for grid search  
grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# GridSearchCV(cv=3, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
#              scoring='f1', verbose=1)

# %%
#good score
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 0.1, 'gamma': 1}
# SVC(C=0.1, gamma=1, random_state=42)

# %%
#clf=SVC(C=100, gamma=0.001,random_state=42) ##0.1
#creating a model with optimal values:
clf=SVC(C=0.1, gamma=1, random_state=42)

# %%
clf.fit(X_train_smote, y_train_smote)
# Out:
# SVC(C=0.1, gamma=1, random_state=42)

# %%
y_clf=clf.predict(X_test)

# %%
cm=pd.crosstab(y_test,y_clf)
cm
# Out:
# col_0     0    1
# Status
# 0       526  344
# 1       150  446

# %%
print(classification_report(y_test,y_clf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.60      0.68       870
#            1       0.56      0.75      0.64       596
#
#     accuracy                           0.66      1466
#    macro avg       0.67      0.68      0.66      1466
# weighted avg       0.69      0.66      0.67      1466

# %% [markdown]
# ## NAIVE BAYES:

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

# %%
# Initialising the model
NB = MultinomialNB()

# %%
# feed data to the model
#NB.fit(xSet_train_CV,ySet_train)
NB.fit(X_train_smote,y_train_smote)
# Out:
# MultinomialNB()

# %%
# prediction for xSet_test_CV

y_predict = NB.predict(X_test)
y_predict
# Out:
# array(['0', '0', '0', ..., '0', '1', '1'], dtype='<U1')

# %%
# classification report

print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.68       870
#            1       0.55      0.63      0.59       596
#
#     accuracy                           0.64      1466
#    macro avg       0.63      0.64      0.63      1466
# weighted avg       0.65      0.64      0.64      1466

# %%
## confusion matrix
pd.crosstab(y_test,y_predict)
# Out:
# col_0     0    1
# Status
# 0       562  308
# 1       220  376

# %%
#Initialising a model
bnb = BernoulliNB()

## fitting the model
bnb.fit(X_train_smote,y_train_smote)

## getting the prediction
y_hat1=bnb.predict(X_test) 

## confusion matrix
pd.crosstab(y_test,y_hat1)
# Out:
# col_0     0    1
# Status
# 0       582  288
# 1       232  364

# %%
y_hat
# Out:
# array(['0', '0', '0', ..., '0', '1', '1'], dtype=object)

# %%
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.62      0.69       870
#            1       0.57      0.72      0.63       596
#
#     accuracy                           0.66      1466
#    macro avg       0.66      0.67      0.66      1466
# weighted avg       0.68      0.66      0.66      1466

# %%
## confusion matrix
pd.crosstab(y_test,y_hat1)
# Out:
# col_0     0    1
# Status
# 0       582  288
# 1       232  364

# %% [markdown]
# ## XGBOOST CLASSIFIER:

# %%
## Installing XGB library

# !pip install xgboost

# %%
X_train_smote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7192 entries, 0 to 7191
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product_ID     7192 non-null   int32
#  1   Source         7192 non-null   int32
#  2   Sales_Agent    7192 non-null   int32
#  3   Location       7192 non-null   int32
#  4   Delivery_Mode  7192 non-null   int32
# dtypes: int32(5)
# memory usage: 140.6 KB

# %%
# Training the model
from xgboost import XGBClassifier
model_xgb = XGBClassifier(n_estimators=450,max_depth=17,gamma=5,learning_rate=0.01,random_state=42)
model_xgb.fit(X_train_smote,y_train_smote)

# %%
# Predicting the model
y_predict_xgb = model_xgb.predict(X_test.values)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Convert y_true to integers
y_true_int = y_test.astype(int)

# Finding accuracy, precision, recall, and confusion matrix
print(accuracy_score(y_true_int, y_predict_xgb))
print(classification_report(y_true_int, y_predict_xgb))

# %%
print(confusion_matrix(y_true_int,y_predict_xgb))

# %% [markdown]
# ## DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier#importing decision tree from sklearn.tree

dt=DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf= 1, min_samples_split= 3, splitter= 'random')#object creation for decision tree  
dt.fit(X_train_smote,y_train_smote)#training the model
y_hat=dt.predict(X_test)#prediction
y_hat#predicted values

# %%
## Evalauting the model
from sklearn.metrics import accuracy_score,classification_report,f1_score    #importing mertics to check model performance
##Training score
y_train_predict=dt.predict(X_train_smote)#passing X_train to predict Y_train
acc_train=accuracy_score(y_train_smote,y_train_predict)#checking accuracy
acc_train

# %%
print(classification_report(y_train_smote,y_train_predict))

# %%
pd.crosstab(y_train_smote,y_train_predict)#it will show you confusion matrix

# %%
train_f1=f1_score(y_train_smote,y_train_predict)
train_f1

# %%
## test acc
test_acc=accuracy_score(y_true_int,y_hat)#testing accuracy 
test_acc

# %%
## test score
test_f1=f1_score(y_true_int,y_hat)#f1 score
test_f1

# %%
pd.crosstab(y_true_int,y_hat)# confusion matrix for

# %% [markdown]
# ### HYPERPARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV
#It helps to loop through predefined hyperparameters and fit your estimator (model) on your training set. 
#So,in the end, you can select the best parameters from the listed hyperparameters.

# %%
#creating dictionary--> key value pair of hyperparameters having key as parameter and values as its values
params = {
    "criterion":("gini", "entropy"), #quality of split
    "splitter":("best", "random"), # searches the features for a split
    "max_depth":(list(range(1, 20))), #depth of tree range from 1 to 19
    "min_samples_split":[2, 3, 4],    #the minimum number of samples required to split internal node
    "min_samples_leaf":list(range(1, 20)),#minimum number of samples required to be at a leaf node,we are passing list which is range from 1 to 19 
}


tree_clf = DecisionTreeClassifier(random_state=42)
tree_cv = GridSearchCV(tree_clf, params, scoring="f1", n_jobs=-1, verbose=1, cv=3)
#passing model to gridsearchCV ,
#tree_clf-->model
#params---->hyperparametes(dictionary we created)
#scoring--->performance matrix to check performance
#n_jobs---->Number of jobs to run in parallel,-1 means using all processors.
#verbose=Controls the verbosity: the higher, the more messages.
#>1 : the computation time for each fold and parameter candidate is displayed;
#>2 : the score is also displayed;
#>3 : the fold and candidate parameter indexes are also displayed together with the starting time of the computation.
#cv------> number of folds


tree_cv.fit(X_train_smote,y_train_smote)#training data on gridsearch cv
best_params = tree_cv.best_params_#it will give you best parameters 
print(f"Best paramters: {best_params})")#printing  best parameters

# %%
tree_cv.best_params_#getting best parameters from cv

# %%
tree_cv.best_score_#getting best score from cv

# %%
dt1=DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_leaf= 1,min_samples_split=2,splitter='best')

# %%
dt1.fit(X_train_smote,y_train_smote)

# %%
y_p_tr = dt1.predict(X_train_smote)

# %%
train_f1=f1_score(y_train_smote,y_p_tr)

# %%
train_f1

# %%
y_hat1=dt1.predict(X_test)#predicting

# %%
acc_test=accuracy_score(y_true_int,y_hat1)#checking accuracy
acc_test

# %%
test_f1=f1_score(y_true_int,y_hat1)#f1_score
test_f1

# %%
print(classification_report(y_true_int,y_hat1))

# %% [markdown]
# ## RANDOM FOREST:

# %%
from sklearn.ensemble import RandomForestClassifier#importing randomforest

rf_clf = RandomForestClassifier(n_estimators=100)#object creation ,taking 100 decision tree in random forest 
rf_clf.fit(X_train_smote,y_train_smote)#training the data

# %%
y_p=rf_clf.predict(X_train_smote)
f1_score(y_train_smote,y_p)

# %%
y_predict=rf_clf.predict(X_test)#testing

# %%
from sklearn.metrics import accuracy_score,classification_report,f1_score 
print(classification_report(y_true_int,y_predict))

# %%
f_Score=f1_score(y_true_int,y_predict)
f_Score

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_true_int,y_predict))
print(classification_report(y_true_int,y_predict))

# %% [markdown]
# ### HYPERPARAMETER TUNING:

# %%
#Random Search sets up a grid of hyperparameter values and selects random combinations to train the model and score.
#This allows you to explicitly control the number of parameter combinations that are attempted.
#The number of search iterations is set based on time or resources.
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]       #Number of decision trees
max_features = ['log2', 'sqrt']                                  #maximum number of features allowed to try in individual tree
max_depth = [int(x) for x in np.linspace(10, 110, num=11)]      #List Comprehension-using for loop in list
min_samples_split = [2, 5, 10]#minimum number of samples required to split an internal node
min_samples_leaf = [1, 2, 4]#minimum number of samples required to be at a leaf node.


#dictionary for hyperparameters
random_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

rf_clf1 = RandomForestClassifier(random_state=42)#model

rf_cv = RandomizedSearchCV(estimator=rf_clf1, scoring='f1',param_distributions=random_grid, n_iter=100, cv=3, 
                               verbose=2, random_state=42, n_jobs=-1)

#estimator--number of decision tree
#scoring--->performance matrix to check performance
#param_distribution-->hyperparametes that we are going to provide 
#n_iter--->Number of combinations to try
##cv------> number of folds
#verbose=Controls the verbosity:the greater the number, the more detail you will get.
#>1 : the computation time for each fold and parameter candidate is displayed;
#>2 : the score is also displayed;
#>3 : the fold and candidate parameter indexes are also displayed together with the starting time of the computation.
#n_jobs----> if you specify n_jobs to -1, it will use all cores in CPU. If it is set to 1 or 2, it will use one or two cores only 





rf_cv.fit(X_train_smote, y_train_smote)                                  ##training data on randomsearch cv
rf_best_params = rf_cv.best_params_                          ##it will give you best parameters 
print(f"Best paramters: {rf_best_params})")                  ##printing  best parameters

# %%
#passing best parameter to randomforest
rf_clf2 = RandomForestClassifier(n_estimators= 200, min_samples_split= 5, min_samples_leaf= 4, 
                                 max_features= 'log2', max_depth= 10)



rf_clf2.fit(X_train_smote, y_train_smote)

y_predict=rf_clf2.predict(X_test)
f1_score(y_true_int,y_predict)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_true_int,y_predict))
print(classification_report(y_true_int,y_predict))

# %% [markdown]
# print(confusion_matrix(y_true_int,y_predict))

# %% [markdown]
# ## CONCLUSION:
#
#
# Upon reviewing the notebook file, it's evident that the analysis was meticulously conducted, encompassing both exploratory data analysis (EDA) and advanced predictive modeling. The initial phase of the analysis focused on understanding the dataset's structure and quality, which involved examining the data's shape, reviewing the first and last few rows, and checking the data types. This phase was crucial for identifying the nature and composition of the dataset, which included a blend of numerical and categorical variables. Additionally, significant attention was given to data cleaning, where unnecessary columns were dropped, and missing values were addressed. This preprocessing stage, including the recategorization of features like 'Product_ID' and 'Status', laid a solid foundation for the subsequent analysis.
#
#
#
# The EDA part of the notebook leveraged both manual techniques and automated tools like Sweetviz to delve into the dataset's characteristics. This approach provided valuable insights into the distribution and relationships among various features, paving the way for more informed data modeling. The latter section of the notebook highlighted the application of a Random Forest Classifier, showcasing an in-depth approach to predictive modeling. The process involved careful hyperparameter tuning using RandomizedSearchCV, ensuring the optimization of the model for better performance. The final model was evaluated using a range of metrics, including F1-score, accuracy, precision, recall, and a confusion matrix. This end-to-end analysis, from detailed data exploration to the deployment of a sophisticated machine learning model, exemplifies a thorough and methodical approach to data science. It underscores the importance of a comprehensive understanding of data characteristics and quality in driving effective predictive modeling, ultimately leading to reliable and actionable insights.
